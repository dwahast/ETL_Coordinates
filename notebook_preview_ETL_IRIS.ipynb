# %% [markdown]
# # ETL IRIS Coordenadas

# %% [markdown]
# ## Funções de extração de dados dos arquivos .txt de entrada

# %%
def extract_lat_lng(file):
    
    f = open(file,'r')
    
    coord = []
    lat = None
    lng = None
    
    for line in f:
        
        if ("Latitude" in line) and lat == None:
            #Talvez essa solução não seja a mais segura (utilizar o S para dividir a linha)
            lat = line.split("S")[1].split("\n")[0]
        if ("Longitude" in line) and (lng == None):
            #Talvez essa solução não seja a mais segura (utilizar o W para dividir a linha)
            lng = line.split("W")[1].split("\n")[0]
            
            coord.append([lat,lng])
            
            lat = None
            lng = None

    print("--Finished Path:",file)
    
    return coord

# %%
def extract_data(files):
    print("Extraindo Dados...")
    #Entrada: Lista de caminhos de arquivos para leitura
    #Saída: Lista com todas coordenadas de todos os arquivos lidos
    
    #lança para o maior número de processos possíveis para se tornar mais eficiente para leitura de diversos arquivos 
    #***cada thread assume um arquivo***
    
    coordinates = []
    
    pool = multiprocessing.Pool(processes=multiprocessing.cpu_count())
    coordinates_temp = pool.map(extract_lat_lng, files)
    
    for f in coordinates_temp:
        coordinates += f
        
    print("--Número de Coordendas total", len(coordinates))

    return coordinates

# %% [markdown]
# ## Funçôes de Transformação das coordenadas extraídas

# %%
def transform_data(coordinates):    
    print("Transformando dados... \n--Aguarde, Requisições à API.")
    #Entrada: Lista com coordenadas agrupadas em listas [[coord1_lat,coord1_lng],[coord2_lat,coord2_lng]]
    #Sáida DataFrame pandas, com as informações obtidas de cada coordenada
    
    #Processo é paralelizada de acordo com as threads disponíveis, visando
    #obter melhor performance na obtenção das informações através da API
    
    pool = multiprocessing.Pool(processes=multiprocessing.cpu_count())
    dict_temp = pool.map(get_location, coordinates)

    df_temp = pd.DataFrame(data=dict_temp)
    
    #Remove as linhas repetidas baseadas na latitudes e longitude, são removidas as linhas com menos valores
    df_temp['count'] = pd.isnull(df_temp).sum(1)
    df_temp = df_temp.sort_values(['count']).drop_duplicates(subset=['latitude','longitude'],keep='first').drop('count',1)
    df_temp.sort_index(inplace=True)
    
    #Remove as linhas as quais o subset é nulo.
    df_temp.dropna(subset=['pais','estado','cidade','bairro'], inplace=True)
    
    df_temp.set_index(['latitude','longitude'], inplace=True)
        
    return df_temp

# %% [markdown]
# ### Função da API geopy para obtenção de informações das coordenas

# %%
import geopy
from geopy.exc import GeocoderTimedOut
from geopy.extra.rate_limiter import RateLimiter

#https://developer.mapquest.com/user/me/apps
#mapquest
CONSUMER_KEY = 'zddGiPAGZEBPTSKYphGuIhSixhyWTcuJ'

df_columns = ["latitude","longitude","rua","numero","bairro","cidade","cep","estado","pais"]
geopy_columns = ["road","house_number","suburb","city","postcode","state","country"]

def get_location(coord):
    
    dict_location = {}
    
    if (coord[0] != None) and (coord[1] != None):
        dict_location['latitude'] = coord[0].strip()
        dict_location['longitude'] = coord[1].strip()
    
        try:
            #https://developer.mapquest.com/user/me/apps
            geolocator = geopy.geocoders.OpenMapQuest(api_key=CONSUMER_KEY)
            RateLimiter(geolocator.reverse, min_delay_seconds=1)
            #geolocator = geopy.geocoders.GoogleV3(api_key = "") 
            location = geolocator.reverse(str(coord[0]) + ", " + str(coord[1]), timeout=10)

        except GeocoderTimedOut as e:
            print("Error: geocode failed on input %s with message %s"%(coord[0]+coord[1], e.message))

        for i in range(2,len(df_columns)):

            try:
                dict_location[df_columns[i]] = location.raw['address'][geopy_columns[i-2]]
            except:
                dict_location[df_columns[i]] = None
    
    return dict_location

# %% [markdown]
# ## Funções do database (conexão, visualização, inserção)

# %%
def print_table_db(table):
    conn = get_connection_db()
    try:
        rows = conn.execute('SELECT * FROM {};'.format(table))
        for n,r in enumerate(rows):
            print(n,r)
    except:
        print("Tabela nao existe")

# %%
import psycopg2
from sqlalchemy import create_engine

def get_connection_db(host_ = 'localhost', dbname_ = 'testeiris', user_ = 'douglas', password_ = '123'):
    try:
        return create_engine(
            'postgresql+psycopg2://{}:{}@{}/{}'.format(user_,password_,host_,dbname_)
            )

    except Exception as e:
        print(e)
        return None

# %%
def remove_df_db_dup(df,db_rows):
    print("--Removendo duplicados presentes no dataframe e database...")
    for i in db_rows:
        try:
            df = df.drop((i[0],i[1]))
        except Exception:
            pass

    return df

# %%
def append_df_in_db(df,conn):
    try:
        df = remove_df_db_dup(df,conn.execute("SELECT * FROM locations"))
        df.to_sql('locations', con = conn, if_exists = 'append', chunksize = 1, index=True)
        print("--Adicionado Novos Valores na Tabela.")
    except:
        try:
            df.to_sql('locations', con = conn, if_exists = 'append', chunksize = 1, index=True)
            conn.execute('ALTER TABLE locations ADD PRIMARY KEY (latitude, longitude);')
            print("--Primeira inserção de valores na tabela.")
        except Exception as e:
            print("--Exeception message:\n",e)

# %%
def load_data(df):
    print("Carregando dados no DB")
    #para utilização é necessário ter um DB.
    #os paramentros de conexão ao DB podem ser alterados
    #host_ = 'localhost', dbname_ = 'testeiris', user_ = 'douglas', password_ = '123'
    conn = get_connection_db()
    append_df_in_db(df, conn)
    conn.dispose()

# %% [markdown]
# ## Main

# %%
import pandas as pd
import multiprocessing
import glob
import time

#Caminho onde se encontram os arquivos .txt contendo as informações de coordenadas
path_master='../ETL_Coordinates/Arquivos Extração'

files = [f for f in glob.glob(path_master + "**/*.txt", recursive=True)]

if len(files) > 0:
    print("\nProcesso de ETL iniciado:\n\n")
    files.sort()

    start = time.time()

    #O processo de extração tem como parametro uma lista de caminho de arquivos
    #a serem extraidas as coordenadas, retornando uma lista com todas as coordenadas
    #de todos os arquivos passados inicialmente (esse processo é feito paralelamente)
    coordinates = extract_data(files)

    #O processe de transformação dos dados tem como parametro a lista de coordenadas
    #as quais serão obtidas as informações como rua, bairro, etc. retornando um dataframe pandas
    df_locations = transform_data(coordinates)

    #O processo de carregamento é feito através da inserção do dataframe em uma tabela prédefinida
    #onde são adicionados os dados ao fim da tabela se ela já existe como também criando a tabela caso não.
    #Esse código pode ser executado diversas vezes com arquivos diferentes como uma única vez com todos os arquivos.
    load_data(df_locations)

    end = time.time()
    
    tempo_total = end - start
    if(float() > 60.0):
        print("\n\nTempo total decorrido:",tempo_total / 60,"m")
    else:
        print("\n\nTempo total decorrido:",tempo_total,"s")

else:
    print("Nenhum arquivo encontrado.")
# Out:
# Extraindo Dados
# Finished Path: ../ETL_Coordinates/Arquivos Extração/data_points_20180102.txt
# Número de Coordendas total 301
# Transformando dados...
# Aguarde, Requisições à API.
# Carregando dados no DB
# Primeira inserção de valores na tabela.
# Tempo total decorrido: 74.22877144813538 s

# %%
#comprovação da inserção de dados no database
print_table_db('locations')
# Out:
# 0 ('-30.06355608', '-51.2331063', None, None, 'Praia de Belas', 'Porto Alegre', '90850-110', 'RS', 'Brasil')
# 1 ('-30.04208508', '-51.25745683', 'Rua Ilha Mauá', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 2 ('-30.03152967', '-51.20818753', 'Viaduto Engenheiro Ildo Meneghetti', None, 'Bom Fim', 'Porto Alegre', '90420-111', 'RS', 'Brasil')
# 3 ('-30.01863604', '-51.19509983', 'Avenida Nova York', '412', 'Auxiliadora', 'Porto Alegre', '90550-070', 'RS', 'Brasil')
# 4 ('-30.07117501', '-51.24203618', None, None, 'Praia de Belas', 'Porto Alegre', '90810-180', 'RS', 'Brasil')
# 5 ('-30.01766564', '-51.26309605', 'Rua Mexiana', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 6 ('-30.03953495', '-51.24244836', None, None, 'Praia de Belas', 'Porto Alegre', '90050-190', 'RS', 'Brasil')
# 7 ('-30.04776623', '-51.19082785', 'Rua Artigas', None, 'Petrópolis', 'Porto Alegre', '90670-160', 'RS', 'Brasil')
# 8 ('-30.05026633', '-51.23414341', None, None, 'Praia de Belas', 'Porto Alegre', '90020-020', 'RS', 'Brasil')
# 9 ('-29.99169173', '-51.22215253', 'Rua 3', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 10 ('-30.04132349', '-51.26787905', 'Rua Marinheiros', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 11 ('-30.05341803', '-51.18583888', 'Rua Afonso Rodrigues', '100', 'Jardim Botânico', 'Porto Alegre', '90690-170', 'RS', 'Brasil')
# 12 ('-30.05887001', '-51.23100554', 'Largo Telmo Thompson Flores', None, 'Praia de Belas', 'Porto Alegre', '90850-100', 'RS', 'Brasil')
# 13 ('-30.0000551', '-51.20736181', 'Avenida da Legalidade e da Democracia', None, 'Navegantes', 'Porto Alegre', '90230-011', 'RS', 'Brasil')
# 14 ('-30.0522143', '-51.25141665', None, None, 'Azenha', 'Porto Alegre', '90130-001', 'RS', 'Brasil')
# 15 ('-30.0656827', '-51.238158', 'Avenida Beira-Rio', None, 'Praia de Belas', 'Porto Alegre', '90810-240', 'RS', 'Brasil')
# 16 ('-30.05574724', '-51.26198648', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 17 ('-30.03197746', '-51.19196556', 'Rua Engenheiro Antônio Rebouças', '74', 'Bela Vista', 'Porto Alegre', '90450-040', 'RS', 'Brasil')
# 18 ('-30.02037698', '-51.17790971', 'Avenida Engenheiro Alfredo Correa Daudt', None, 'Boa Vista', 'Porto Alegre', '90520-002', 'RS', 'Brasil')
# 19 ('-30.03680744', '-51.24121034', None, None, 'Centro Histórico', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 20 ('-30.04844249', '-51.24540241', None, None, 'Praia de Belas', 'Porto Alegre', '90050-190', 'RS', 'Brasil')
# 21 ('-30.01904974', '-51.20735485', 'Rua Emancipação', None, 'Floresta', 'Porto Alegre', '95220-075', 'RS', 'Brasil')
# 22 ('-30.06904449', '-51.21514414', 'Avenida Tronco', '150', 'Santa Tereza', 'Porto Alegre', '90880-310', 'RS', 'Brasil')
# 23 ('-30.00930695', '-51.25534257', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 24 ('-30.04618079', '-51.18826417', 'Rua Borges do Canto', None, 'Petrópolis', 'Porto Alegre', '90670-160', 'RS', 'Brasil')
# 25 ('-30.02107709', '-51.24780217', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 26 ('-30.07447642', '-51.21914296', None, None, 'Santa Tereza', 'Porto Alegre', '90840-600', 'RS', 'Brasil')
# 27 ('-30.03233494', '-51.20458209', 'Rua Vasco da Gama', None, 'Rio Branco', 'Porto Alegre', '90420-090', 'RS', 'Brasil')
# 28 ('-30.05145559', '-51.20554879', 'Rua Santana', None, 'Santana', 'Porto Alegre', '90040-373', 'RS', 'Brasil')
# 29 ('-30.03506026', '-51.25916386', 'Beco 298', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 30 ('-30.01497912', '-51.21558933', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 31 ('-30.01742408', '-51.21391713', 'Rua Voluntários da Pátria', '1940', 'Floresta', 'Porto Alegre', '90230-010', 'RS', 'Brasil')
# 32 ('-30.01757847', '-51.1811804', 'Rua Coronel Feijó', None, 'Higienópolis', 'Porto Alegre', '90520-003', 'RS', 'Brasil')
# 33 ('-30.04246339', '-51.21127184', 'Rua Laurindo', None, 'Santana', 'Porto Alegre', '90040-370', 'RS', 'Brasil')
# 34 ('-30.05873133', '-51.26042534', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 35 ('-30.04854904', '-51.19957855', 'Rua São Francisco', None, 'Santana', 'Porto Alegre', '90620-110', 'RS', 'Brasil')
# 36 ('-30.01094349', '-51.24016926', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 37 ('-30.02085829', '-51.23057835', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 38 ('-30.02460753', '-51.1857063', 'Rua Campos Sales', None, 'Montserrat', 'Porto Alegre', '90550-110', 'RS', 'Brasil')
# 39 ('-30.06151562', '-51.17944692', 'Avenida Bento Gonçalves', '3722', 'Partenon', 'Porto Alegre', '90650-001', 'RS', 'Brasil')
# 40 ('-30.07706118', '-51.22422123', 'Acesso 80', None, 'Santa Tereza', 'Porto Alegre', '90830-585', 'RS', 'Brasil')
# 41 ('-30.06751143', '-51.20168697', 'Rua Martim Minaberry', None, 'Santo Antônio', 'Porto Alegre', '90660-120', 'RS', 'Brasil')
# 42 ('-30.03662125', '-51.24414265', None, None, 'Praia de Belas', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 43 ('-29.99864562', '-51.20223785', 'Avenida Sertório', None, 'Navegantes', 'Porto Alegre', '90230-000', 'RS', 'Brasil')
# 44 ('-30.00032913', '-51.21660965', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 45 ('-30.04000976', '-51.20765215', 'Rua Ramiro Barcelos', '21112', 'Santa Cecília', 'Porto Alegre', '91160-093', 'RS', 'Brasil')
# 46 ('-30.0670264', '-51.22037851', 'Rua Cleveland', None, 'Santa Tereza', 'Porto Alegre', '90850-240', 'RS', 'Brasil')
# 47 ('-30.07350916', '-51.21626519', 'Rua Poscar Tollens', None, 'Santa Tereza', 'Porto Alegre', '90880-310', 'RS', 'Brasil')
# 48 ('-30.05515563', '-51.26261124', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 49 ('-30.06156373', '-51.23662122', 'Avenida Beira-Rio', None, 'Praia de Belas', 'Porto Alegre', '90850-100', 'RS', 'Brasil')
# 50 ('-30.0567747', '-51.23728497', 'Avenida Beira-Rio', None, 'Praia de Belas', 'Porto Alegre', '90020-020', 'RS', 'Brasil')
# 51 ('-30.07444829', '-51.1984127', 'Rua Pedro Boticário', '654', 'Glória', 'Porto Alegre', '90660-070', 'RS', 'Brasil')
# 52 ('-29.9939049', '-51.22550763', 'Rua 1', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 53 ('-30.03988424', '-51.17367305', 'Avenida Senador Tarso Dutra', None, 'Petrópolis', 'Porto Alegre', '90690-140', 'RS', 'Brasil')
# 54 ('-30.06608837', '-51.24689578', None, None, 'Praia de Belas', 'Porto Alegre', None, 'RS', 'Brasil')
# 55 ('-30.02112025', '-51.19308479', 'Rua 24 de Outubro', '1538', 'Auxiliadora', 'Porto Alegre', '90510-001', 'RS', 'Brasil')
# 56 ('-30.04013153', '-51.1969291', 'Avenida Protásio Alves', None, 'Santa Cecília', 'Porto Alegre', '90420-041', 'RS', 'Brasil')
# 57 ('-30.03381251', '-51.19964171', 'Rua Vasco da Gama', None, 'Rio Branco', 'Porto Alegre', '90420-060', 'RS', 'Brasil')
# 58 ('-29.99160284', '-51.20747717', 'Rua João Moreira Maciel', None, 'Navegantes', 'Porto Alegre', '90230-011', 'RS', 'Brasil')
# 59 ('-30.01325311', '-51.23644041', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 60 ('-30.01526163', '-51.17740842', 'Rua Valentim Vicentini', '255', 'Passo da Areia', 'Porto Alegre', '90520-220', 'RS', 'Brasil')
# 61 ('-30.07664118', '-51.22728151', 'Beco 1', None, 'Santa Tereza', 'Porto Alegre', '90840-030', 'RS', 'Brasil')
# 62 ('-30.02409939', '-51.18015107', 'Avenida Engenheiro Alfredo Correa Daudt', None, 'Boa Vista', 'Porto Alegre', '90520-002', 'RS', 'Brasil')
# 63 ('-30.0412541', '-51.23472108', 'Avenida Glaucus Saraiva', None, 'Praia de Belas', 'Porto Alegre', '90010-390', 'RS', 'Brasil')
# 64 ('-30.05557165', '-51.2014497', 'Rua Luiz de Camões', '372', 'Santo Antônio', 'Porto Alegre', '90620-150', 'RS', 'Brasil')
# 65 ('-30.0582646', '-51.19836657', 'Avenida Bento Gonçalves', None, 'Santo Antônio', 'Porto Alegre', '90620-002', 'RS', 'Brasil')
# 66 ('-30.04743556', '-51.21174198', 'Avenida João Pessoa', '2050', 'Santana', 'Porto Alegre', '90620-001', 'RS', 'Brasil')
# 67 ('-29.99983665', '-51.23945205', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 68 ('-30.03271911', '-51.24213635', 'Avenida Presidente João Goulart', '501', 'Centro Histórico', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 69 ('-30.00155782', '-51.2042256', 'Rua Doutor João Inácio', None, 'Navegantes', 'Porto Alegre', '90230-000', 'RS', 'Brasil')
# 70 ('-30.03114781', '-51.25122645', 'Rua Ilha Mauá', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 71 ('-30.00880521', '-51.25478606', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 72 ('-30.05837435', '-51.22506094', 'Rua Múcio Teixeira', None, 'Menino Deus', 'Porto Alegre', '90880-480', 'RS', 'Brasil')
# 73 ('-30.00332602', '-51.20551451', 'Avenida Cairú', None, 'Navegantes', 'Porto Alegre', '90230-220', 'RS', 'Brasil')
# 74 ('-30.06355217', '-51.22647971', 'Rua Barão de Cerro Largo', None, 'Menino Deus', 'Porto Alegre', '90850-110', 'RS', 'Brasil')
# 75 ('-30.04896246', '-51.22890845', 'Avenida Praia de Belas', '1181', 'Praia de Belas', 'Porto Alegre', '90110-903', 'RS', 'Brasil')
# 76 ('-30.02458513', '-51.20295843', 'Rua Padre Chagas', '310', 'Moinhos de Vento', 'Porto Alegre', '90510-000', 'RS', 'Brasil')
# 77 ('-30.0459803', '-51.25433368', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 78 ('-30.04141392', '-51.24722901', None, None, 'Praia de Belas', 'Porto Alegre', '90050-190', 'RS', 'Brasil')
# 79 ('-30.04816439', '-51.25848537', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 80 ('-30.01074752', '-51.18489586', 'Rua Honório Silveira Dias', '844', 'São João', 'Porto Alegre', '90550-150', 'RS', 'Brasil')
# 81 ('-30.07430938', '-51.24096111', 'Avenida Padre Cacique', None, 'Cristal', 'Porto Alegre', '90810-180', 'RS', 'Brasil')
# 82 ('-30.00926772', '-51.21504893', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 83 ('-30.0477014', '-51.17488892', 'Rua Engenheiro Antônio Carlos Tibiriçá', None, 'Jardim Botânico', 'Porto Alegre', '91410-140', 'RS', 'Brasil')
# 84 ('-30.05722576', '-51.17496048', 'Avenida Ipiranga', '6681', 'Partenon', 'Porto Alegre', '91410-000', 'RS', 'Brasil')
# 85 ('-30.04226044', '-51.19758662', 'Rua Santa Cecília', None, 'Santa Cecília', 'Porto Alegre', '90420-041', 'RS', 'Brasil')
# 86 ('-30.05350251', '-51.24172512', None, None, 'Azenha', 'Porto Alegre', '90130-001', 'RS', 'Brasil')
# 87 ('-30.02709826', '-51.21307829', 'Avenida Cristóvão Colombo', None, 'Independência', 'Porto Alegre', '90560-003', 'RS', 'Brasil')
# 88 ('-30.07587702', '-51.21944582', 'Avenida Joracy Camargo', None, 'Santa Tereza', 'Porto Alegre', '90840-360', 'RS', 'Brasil')
# 89 ('-30.00397094', '-51.22487643', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 90 ('-29.99945099', '-51.18992272', 'Rua 18 de Novembro', None, 'São João', 'Porto Alegre', '91020-001', 'RS', 'Brasil')
# 91 ('-30.02328311', '-51.19584775', 'Rua 24 de Outubro', '1305', 'Auxiliadora', 'Porto Alegre', '90510-003', 'RS', 'Brasil')
# 92 ('-30.03128781', '-51.23622541', 'Rua General Canabarro', None, 'Centro Histórico', 'Porto Alegre', '90010-160', 'RS', 'Brasil')
# 93 ('-30.02814372', '-51.22295008', 'Avenida Alberto Bins', None, 'Centro Histórico', 'Porto Alegre', '90030-140', 'RS', 'Brasil')
# 94 ('-30.03804287', '-51.2678474', 'Rua Marinheiros', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 95 ('-30.05237268', '-51.24128091', None, None, 'Azenha', 'Porto Alegre', '90130-001', 'RS', 'Brasil')
# 96 ('-30.02445699', '-51.23104455', 'Faixa Portuária', None, 'Centro Histórico', 'Porto Alegre', '90010-110', 'RS', 'Brasil')
# 97 ('-30.0046983', '-51.21137289', 'Faixa Portuária', None, 'São Geraldo', 'Porto Alegre', '90230-110', 'RS', 'Brasil')
# 98 ('-30.00539065', '-51.20299854', 'Avenida Brasil', '483', 'São Geraldo', 'Porto Alegre', '90230-001', 'RS', 'Brasil')
# 99 ('-30.01810034', '-51.25988793', 'Avenida Presidente Vargas', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 100 ('-30.03611749', '-51.21741451', None, None, 'Farroupilha', 'Porto Alegre', '90050-340', 'RS', 'Brasil')
# 101 ('-30.03085511', '-51.25530945', None, None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 102 ('-30.02747546', '-51.18413436', 'Rua Anita Garibaldi', None, 'Montserrat', 'Porto Alegre', '90470-130', 'RS', 'Brasil')
# 103 ('-30.04577956', '-51.17572112', 'Avenida Senador Tarso Dutra', None, 'Petrópolis', 'Porto Alegre', '90690-140', 'RS', 'Brasil')
# 104 ('-30.04029565', '-51.25787483', 'Rua Ilha Mauá', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 105 ('-30.03044151', '-51.18606103', 'Rua Comendador Rheingantz', None, 'Bela Vista', 'Porto Alegre', '90450-170', 'RS', 'Brasil')
# 106 ('-30.02454734', '-51.24195902', 'Faixa Portuária', None, 'Centro Histórico', 'Porto Alegre', '90012-970', 'RS', 'Brasil')
# 107 ('-30.02611325', '-51.17084911', 'Avenida Frei Caneca', None, 'Boa Vista', 'Porto Alegre', '91340-400', 'RS', 'Brasil')
# 108 ('-30.0590207', '-51.20452591', 'Rua Teixeira de Freitas', None, 'Santo Antônio', 'Porto Alegre', '90640-050', 'RS', 'Brasil')
# 109 ('-30.06642192', '-51.19775253', 'Rua Barão do Amazonas', None, 'Partenon', 'Porto Alegre', '90680-090', 'RS', 'Brasil')
# 110 ('-30.00892002', '-51.24279499', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 111 ('-29.99374357', '-51.2133433', 'Travessia Régis Bitencourt', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 112 ('-30.05498101', '-51.20488952', 'Rua Doutor Julio Bocaccio', None, 'Santo Antônio', 'Porto Alegre', '90620-130', 'RS', 'Brasil')
# 113 ('-30.00930223', '-51.20214611', 'Avenida Farrapos', '2646', 'São Geraldo', 'Porto Alegre', '90220-004', 'RS', 'Brasil')
# 114 ('-30.00502479', '-51.2364938', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 115 ('-30.01382581', '-51.22556915', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 116 ('-30.03025191', '-51.19380936', 'Avenida Coronel Lucas de Oliveira', '894', 'Bela Vista', 'Porto Alegre', '90440-010', 'RS', 'Brasil')
# 117 ('-30.01414817', '-51.25793701', 'Rua Doutor Salomão Pires Abrahão', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 118 ('-30.02756004', '-51.22829737', None, None, 'Centro Histórico', 'Porto Alegre', '90020-070', 'RS', 'Brasil')
# 119 ('-30.00372147', '-51.23793927', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 120 ('-30.02425683', '-51.26808106', 'Rua Mexiana', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 121 ('-30.02927007', '-51.1973856', 'Rua Dona Laura', None, 'Rio Branco', 'Porto Alegre', '90430-090', 'RS', 'Brasil')
# 122 ('-30.0056011', '-51.21050487', 'Faixa Portuária', None, 'São Geraldo', 'Porto Alegre', '90230-110', 'RS', 'Brasil')
# 123 ('-30.03859316', '-51.231233', 'Rua Antônio Klinger Filho', None, 'Praia de Belas', 'Porto Alegre', '90010-460', 'RS', 'Brasil')
# 124 ('-30.03584078', '-51.19316129', 'Rua Barão de Ubá', None, 'Bela Vista', 'Porto Alegre', '90460-001', 'RS', 'Brasil')
# 125 ('-30.01562261', '-51.23674893', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 126 ('-30.02839064', '-51.22201883', 'Avenida Alberto Bins', '467', 'Independência', 'Porto Alegre', '90030-142', 'RS', 'Brasil')
# 127 ('-30.03523115', '-51.21890221', 'Avenida Beira Lago', None, 'Farroupilha', 'Porto Alegre', '90040-060', 'RS', 'Brasil')
# 128 ('-30.05224382', '-51.22985777', 'Avenida Borges de Medeiros', None, 'Praia de Belas', 'Porto Alegre', '90110-001', 'RS', 'Brasil')
# 129 ('-30.0687195', '-51.24986142', None, None, 'Praia de Belas', 'Porto Alegre', None, 'RS', 'Brasil')
# 130 ('-30.02980344', '-51.17765741', 'Alameda Emílio Menezes', None, '3 Figueiras', 'Porto Alegre', '91340-310', 'RS', 'Brasil')
# 131 ('-30.05531359', '-51.24818572', None, None, 'Azenha', 'Porto Alegre', '90130-001', 'RS', 'Brasil')
# 132 ('-30.00055655', '-51.21015882', 'Faixa Portuária', None, 'São Geraldo', 'Porto Alegre', '90230-110', 'RS', 'Brasil')
# 133 ('-30.03776366', '-51.22134846', 'Rua General Lima e Silva', '560', 'Cidade Baixa', 'Porto Alegre', '90050-340', 'RS', 'Brasil')
# 134 ('-30.05701757', '-51.22834928', 'Avenida Praia de Belas', '1948', 'Menino Deus', 'Porto Alegre', '90110-001', 'RS', 'Brasil')
# 135 ('-30.0025353', '-51.2018172', 'Avenida França', None, 'Navegantes', 'Porto Alegre', '90230-220', 'RS', 'Brasil')
# 136 ('-30.01200201', '-51.1764475', 'Rua Nova Prata', None, 'Passo da Areia', 'Porto Alegre', '90520-280', 'RS', 'Brasil')
# 137 ('-30.00403283', '-51.22184685', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 138 ('-30.06196109', '-51.189354', 'Avenida Bento Gonçalves', None, 'Partenon', 'Porto Alegre', '90650-000', 'RS', 'Brasil')
# 139 ('-29.99702406', '-51.232491', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 140 ('-30.01676669', '-51.24739682', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 141 ('-30.0165809', '-51.25547532', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 142 ('-30.05877011', '-51.25759244', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 143 ('-30.04977843', '-51.22919125', 'Avenida Borges de Medeiros', '2500', 'Praia de Belas', 'Porto Alegre', '90110-150', 'RS', 'Brasil')
# 144 ('-30.05756793', '-51.21603602', 'Rua Damasco', None, 'Azenha', 'Porto Alegre', '90160-181', 'RS', 'Brasil')
# 145 ('-30.00236109', '-51.22639577', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 146 ('-30.02733689', '-51.19366251', 'Rua Anita Garibaldi', '233', 'Montserrat', 'Porto Alegre', '90450-001', 'RS', 'Brasil')
# 147 ('-30.02149924', '-51.17602114', 'Rua Frei Henrique Golland Trindade', None, 'Boa Vista', 'Porto Alegre', '91340-410', 'RS', 'Brasil')
# 148 ('-30.02990006', '-51.23323204', 'Rua Siqueira Campos', None, 'Centro Histórico', 'Porto Alegre', '90012-970', 'RS', 'Brasil')
# 149 ('-30.03699201', '-51.23722788', None, None, 'Praia de Belas', 'Porto Alegre', '90013-900', 'RS', 'Brasil')
# 150 ('-30.03423838', '-51.17711576', 'Avenida Luiz Manoel Gonzaga', '450', '3 Figueiras', 'Porto Alegre', '90470-260', 'RS', 'Brasil')
# 151 ('-30.02487026', '-51.25017761', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 152 ('-29.9970987', '-51.22729216', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 153 ('-30.04186271', '-51.19086514', 'Avenida Protásio Alves', None, 'Petrópolis', 'Porto Alegre', '90410-005', 'RS', 'Brasil')
# 154 ('-30.03226922', '-51.24423916', 'Avenida Presidente João Goulart', None, 'Centro Histórico', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 155 ('-30.00234678', '-51.21947722', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 156 ('-30.05077735', '-51.23426934', None, None, 'Praia de Belas', 'Porto Alegre', '90020-020', 'RS', 'Brasil')
# 157 ('-30.02978769', '-51.22118902', 'Avenida Independência', '75', 'Centro Histórico', 'Porto Alegre', '90030-142', 'RS', 'Brasil')
# 158 ('-30.04157915', '-51.26496703', 'Rua Marinheiros', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 159 ('-30.01877816', '-51.19513762', 'Avenida Nova York', '335', 'Auxiliadora', 'Porto Alegre', '90550-070', 'RS', 'Brasil')
# 160 ('-30.06952063', '-51.23291426', 'Alameda Jacarandá', None, 'Santa Tereza', 'Porto Alegre', '90850-080', 'RS', 'Brasil')
# 161 ('-30.00277886', '-51.22597767', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 162 ('-30.03024771', '-51.20675671', 'Rua Castro Alves', '402', 'Bom Fim', 'Porto Alegre', '90035-073', 'RS', 'Brasil')
# 163 ('-30.0074752', '-51.20402204', 'Avenida São Paulo', None, 'São Geraldo', 'Porto Alegre', '90230-090', 'RS', 'Brasil')
# 164 ('-30.03484253', '-51.18453989', 'Rua Sioma Breitman', None, 'Petrópolis', 'Porto Alegre', '90470-150', 'RS', 'Brasil')
# 165 ('-30.00886782', '-51.22517363', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 166 ('-30.07038209', '-51.2355237', 'Rua Dona Antônia', None, 'Santa Tereza', 'Porto Alegre', '90840-690', 'RS', 'Brasil')
# 167 ('-30.02466008', '-51.2541366', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 168 ('-30.00629064', '-51.17845992', 'Rua Morretes', '222', 'Santa Maria Goretti', 'Porto Alegre', '91030-300', 'RS', 'Brasil')
# 169 ('-30.02232193', '-51.2047945', 'Rua Santo Inacio', None, 'Moinhos de Vento', 'Porto Alegre', '90570-140', 'RS', 'Brasil')
# 170 ('-30.02584632', '-51.17353624', 'Avenida Marechal Andréa', '345', 'Boa Vista', 'Porto Alegre', '91340-400', 'RS', 'Brasil')
# 171 ('-30.07762624', '-51.20692798', None, None, 'Glória', 'Porto Alegre', '91720-090', 'RS', 'Brasil')
# 172 ('-30.06821957', '-51.23549669', 'Avenida Padre Cacique', '1028', 'Santa Tereza', 'Porto Alegre', '90810-240', 'RS', 'Brasil')
# 173 ('-30.05100915', '-51.19249185', 'Rua La Plata', None, 'Jardim Botânico', 'Porto Alegre', '90610-000', 'RS', 'Brasil')
# 174 ('-30.01206553', '-51.25150481', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 175 ('-30.05564862', '-51.26000423', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 176 ('-30.0683285', '-51.2515185', None, None, 'Praia de Belas', 'Porto Alegre', None, 'RS', 'Brasil')
# 177 ('-30.00218232', '-51.24259851', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 178 ('-30.07154007', '-51.23925082', 'Avenida Padre Cacique', None, 'Santa Tereza', 'Porto Alegre', '90810-240', 'RS', 'Brasil')
# 179 ('-30.01287812', '-51.26070542', 'Rua Capitão Coelho', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 180 ('-30.02580008', '-51.19022979', 'Rua Silva Jardim', None, 'Montserrat', 'Porto Alegre', '90450-000', 'RS', 'Brasil')
# 181 ('-30.00573227', '-51.18236693', 'Rua 25 de Julho', None, 'São João', 'Porto Alegre', '91030-280', 'RS', 'Brasil')
# 182 ('-30.03468871', '-51.22269354', 'Rua Sarmento Leite', None, 'Cidade Baixa', 'Porto Alegre', '90050-170', 'RS', 'Brasil')
# 183 ('-30.06000206', '-51.2297902', 'Avenida Padre Cacique', None, 'Menino Deus', 'Porto Alegre', '90850-100', 'RS', 'Brasil')
# 184 ('-30.03884168', '-51.19910825', 'Rua São Vicente', None, 'Rio Branco', 'Porto Alegre', '90420-020', 'RS', 'Brasil')
# 185 ('-30.00766032', '-51.22349544', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 186 ('-30.00866102', '-51.18959762', 'Rua Barão de Cotegipe', None, 'São João', 'Porto Alegre', '90540-020', 'RS', 'Brasil')
# 187 ('-30.04242313', '-51.25306089', 'Rua Ilha Mauá', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 188 ('-30.06642392', '-51.19209283', 'Rua Joaquim Norberto', None, 'Partenon', 'Porto Alegre', '90680-090', 'RS', 'Brasil')
# 189 ('-30.04012029', '-51.17402488', 'Avenida Senador Tarso Dutra', None, 'Petrópolis', 'Porto Alegre', '90690-140', 'RS', 'Brasil')
# 190 ('-30.02268285', '-51.22559101', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 191 ('-30.00594663', '-51.24546817', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 192 ('-29.99853535', '-51.24584283', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 193 ('-30.02601415', '-51.1948209', 'Rua Tenente Coronel Fabricio Pilar', None, 'Montserrat', 'Porto Alegre', '90450-001', 'RS', 'Brasil')
# 194 ('-30.00224394', '-51.20383386', 'Avenida Santos Dumont', None, 'Navegantes', 'Porto Alegre', '90230-220', 'RS', 'Brasil')
# 195 ('-30.0182302', '-51.17089343', 'Rua Azevedo Sodré', None, 'Passo da Areia', 'Porto Alegre', '90520-360', 'RS', 'Brasil')
# 196 ('-30.00869291', '-51.22952773', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 197 ('-30.04539502', '-51.22133951', 'Avenida Getúlio Vargas', '100', 'Menino Deus', 'Porto Alegre', '90050-340', 'RS', 'Brasil')
# 198 ('-30.01752591', '-51.25535452', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 199 ('-30.00855763', '-51.24311313', 'Rua dos Pescadores', None, 'Arquipélago', 'Porto Alegre', '90090-040', 'RS', 'Brasil')
# 200 ('-30.06432895', '-51.20806327', 'Rua Oscar Schneider', None, 'Medianeira', 'Porto Alegre', '90880-410', 'RS', 'Brasil')
# 201 ('-30.01840446', '-51.24709476', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 202 ('-30.04833997', '-51.22013324', None, None, 'Praia de Belas', 'Porto Alegre', '90160-090', 'RS', 'Brasil')
# 203 ('-30.05090478', '-51.20506969', 'Rua Vicente da Fontoura', None, 'Santana', 'Porto Alegre', '90620-110', 'RS', 'Brasil')
# 204 ('-30.06389675', '-51.22126833', 'Rua Correa Lima', None, 'Santa Tereza', 'Porto Alegre', '90850-180', 'RS', 'Brasil')
# 205 ('-30.04229561', '-51.25853606', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 206 ('-30.00779613', '-51.22005764', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 207 ('-30.0087204', '-51.23298139', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 208 ('-30.05239437', '-51.17202184', 'Rua Professor Cristiano Fischer', None, 'Jardim Botânico', 'Porto Alegre', '91410-000', 'RS', 'Brasil')
# 209 ('-30.06069503', '-51.20897847', 'Avenida Professor Oscar Pereira', None, 'Santo Antônio', 'Porto Alegre', '90640-050', 'RS', 'Brasil')
# 210 ('-30.01654462', '-51.24039175', 'Faixa Portuária', None, 'Centro Histórico', 'Porto Alegre', '90012-970', 'RS', 'Brasil')
# 211 ('-30.02470954', '-51.22708453', 'Avenida Mauá', '1050', 'Centro Histórico', 'Porto Alegre', '90010-110', 'RS', 'Brasil')
# 212 ('-30.07416333', '-51.20474543', 'Rua Luiza Rocco', None, 'Glória', 'Porto Alegre', '90870-050', 'RS', 'Brasil')
# 213 ('-30.05392834', '-51.17315419', 'Rua Professor Cristiano Fischer', None, 'Jardim Botânico', 'Porto Alegre', '91410-000', 'RS', 'Brasil')
# 214 ('-30.00397449', '-51.22381851', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 215 ('-30.04718945', '-51.21867693', 'Avenida Érico Veríssimo', '307', 'Menino Deus', 'Porto Alegre', '90050-340', 'RS', 'Brasil')
# 216 ('-30.05193008', '-51.18174895', 'Rua Felizardo', None, 'Jardim Botânico', 'Porto Alegre', '90690-170', 'RS', 'Brasil')
# 217 ('-30.05864531', '-51.24318238', None, None, 'Praia de Belas', 'Porto Alegre', None, 'RS', 'Brasil')
# 218 ('-30.05601693', '-51.22446985', 'Rua Gumercindo Saraiva', None, 'Menino Deus', 'Porto Alegre', '90150-005', 'RS', 'Brasil')
# 219 ('-30.03448869', '-51.23531784', 'Rua General Cypriano Ferreira', '480', 'Centro Histórico', 'Porto Alegre', '90010-330', 'RS', 'Brasil')
# 220 ('-30.00325266', '-51.2267502', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 221 ('-30.05141664', '-51.19345388', 'Avenida Ipiranga', '3884', 'Jardim Botânico', 'Porto Alegre', '90620-270', 'RS', 'Brasil')
# 222 ('-30.02593169', '-51.22310159', 'Rua Chaves Barcelos', None, 'Centro Histórico', 'Porto Alegre', '91010-003', 'RS', 'Brasil')
# 223 ('-30.06319506', '-51.22987866', 'Avenida Padre Cacique', None, 'Menino Deus', 'Porto Alegre', '90850-100', 'RS', 'Brasil')
# 224 ('-30.07252493', '-51.23023524', 'Rua Rio Branco', None, 'Santa Tereza', 'Porto Alegre', '90850-250', 'RS', 'Brasil')
# 225 ('-30.01466686', '-51.22742266', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 226 ('-30.02162136', '-51.23135267', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 227 ('-30.02954875', '-51.18287431', 'Avenida Nilo Peçanha', None, 'Bela Vista', 'Porto Alegre', '90480-003', 'RS', 'Brasil')
# 228 ('-30.00588302', '-51.21201431', 'Faixa Portuária', None, 'São Geraldo', 'Porto Alegre', '90230-110', 'RS', 'Brasil')
# 229 ('-30.02505232', '-51.24513562', 'Avenida Nossa Senhora da Boa Viagem', None, 'Arquipélago', 'Porto Alegre', '90090-140', 'RS', 'Brasil')
# 230 ('-30.05188229', '-51.19903694', 'Rua São Manoel', None, 'Santana', 'Porto Alegre', '90610-010', 'RS', 'Brasil')
# 231 ('-30.01739287', '-51.20980611', 'Rua Leopoldo Froes', None, 'Floresta', 'Porto Alegre', '90220-170', 'RS', 'Brasil')
# 232 ('-30.04103739', '-51.26556945', 'Rua Marinheiros', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 233 ('-30.07293638', '-51.22545934', 'Rua Banco Inglês', None, 'Santa Tereza', 'Porto Alegre', '90840-030', 'RS', 'Brasil')
# 234 ('-30.07337942', '-51.19635339', None, None, 'Glória', 'Porto Alegre', '90680-540', 'RS', 'Brasil')
# 235 ('-30.01953135', '-51.21121523', 'Rua Comendador Azevedo', None, 'Floresta', 'Porto Alegre', '90220-004', 'RS', 'Brasil')
# 236 ('-30.02430704', '-51.21616776', 'Rua Santo Antônio', '1613', 'Floresta', 'Porto Alegre', '90220-000', 'RS', 'Brasil')
# 237 ('-30.03513433', '-51.25165173', 'Rua Ilha Mauá', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 238 ('-29.99411497', '-51.22950688', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 239 ('-30.02006902', '-51.21340103', 'Rua Ramiro Barcelos', '104', 'Floresta', 'Porto Alegre', '90030-010', 'RS', 'Brasil')
# 240 ('-30.03671456', '-51.26675749', 'Rua Marinheiros', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 241 ('-30.01151614', '-51.19874322', 'Avenida São Pedro', None, 'São Geraldo', 'Porto Alegre', '90230-124', 'RS', 'Brasil')
# 242 ('-29.99416427', '-51.21283607', 'Ponte do Guaíba', None, 'Arquipélago', 'Porto Alegre', '90230-011', 'RS', 'Brasil')
# 243 ('-30.03210246', '-51.16728256', 'Rua Professor Fernando Carneiro', '83', '3 Figueiras', 'Porto Alegre', '91330-050', 'RS', 'Brasil')
# 244 ('-30.04023383', '-51.24172881', None, None, 'Praia de Belas', 'Porto Alegre', '90050-190', 'RS', 'Brasil')
# 245 ('-30.0034551', '-51.24214113', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 246 ('-30.05029526', '-51.22517013', 'Avenida Bastian', '270', 'Menino Deus', 'Porto Alegre', '90130-020', 'RS', 'Brasil')
# 247 ('-30.02171409', '-51.24128438', 'Faixa Portuária', None, 'Centro Histórico', 'Porto Alegre', '90012-970', 'RS', 'Brasil')
# 248 ('-29.99461405', '-51.2186749', 'Travessia Régis Bitencourt', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 249 ('-30.02326162', '-51.2189523', 'Largo Vespasiano Júlio Veppo', '70', 'Floresta', 'Porto Alegre', '90035-040', 'RS', 'Brasil')
# 250 ('-30.04785928', '-51.17881845', 'Rua Doutor Salvador França', '1800', 'Jardim Botânico', 'Porto Alegre', '90690-000', 'RS', 'Brasil')
# 251 ('-30.04841642', '-51.23062593', 'Alameda Alexandre Zilles Barata', None, 'Praia de Belas', 'Porto Alegre', '90110-150', 'RS', 'Brasil')
# 252 ('-30.04942659', '-51.19211434', 'Rua Doutor Veridiano Farias', '122', 'Petrópolis', 'Porto Alegre', '90610-000', 'RS', 'Brasil')
# 253 ('-30.05878321', '-51.21888105', 'Rua Almirante Gonçalves', None, 'Menino Deus', 'Porto Alegre', '90130-060', 'RS', 'Brasil')
# 254 ('-30.06780466', '-51.20875318', 'Avenida Niterói', None, 'Medianeira', 'Porto Alegre', '90880-270', 'RS', 'Brasil')
# 255 ('-30.07667206', '-51.2344799', 'Beco do Aperto', None, 'Santa Tereza', 'Porto Alegre', '90850-250', 'RS', 'Brasil')
# 256 ('-30.01975426', '-51.21103124', 'Avenida Farrapos', '1122', 'Floresta', 'Porto Alegre', '90220-004', 'RS', 'Brasil')
# 257 ('-30.03543094', '-51.2273265', 'Rua Marechal Floriano Peixoto', None, 'Centro Histórico', 'Porto Alegre', '90020-025', 'RS', 'Brasil')
# 258 ('-29.99894189', '-51.21452941', 'Faixa Portuária', None, 'São Geraldo', 'Porto Alegre', '90230-110', 'RS', 'Brasil')
# 259 ('-30.01467327', '-51.1809387', 'Rua General Couto de Magalhães', None, 'Higienópolis', 'Porto Alegre', '90520-100', 'RS', 'Brasil')
# 260 ('-30.02918567', '-51.17909905', None, None, 'Boa Vista', 'Porto Alegre', '91340-310', 'RS', 'Brasil')
# 261 ('-30.04287231', '-51.20848543', 'Rua Jacinto Gomes', None, 'Santana', 'Porto Alegre', '91160-093', 'RS', 'Brasil')
# 262 ('-30.0148143', '-51.22232511', 'Rua João Inácio da Silveira', None, 'Arquipélago', 'Porto Alegre', '90090-260', 'RS', 'Brasil')
# 263 ('-30.02266265', '-51.23784871', 'Faixa Portuária', None, 'Centro Histórico', 'Porto Alegre', '90012-970', 'RS', 'Brasil')
# 264 ('-30.05921201', '-51.2165242', 'Avenida Coronel Gastão Hasslocher Mazeron', None, 'Medianeira', 'Porto Alegre', '90880-440', 'RS', 'Brasil')
# 265 ('-30.01964676', '-51.22122931', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 266 ('-30.04251938', '-51.20363992', 'Rua Felipe de Oliveira', None, 'Santa Cecília', 'Porto Alegre', '90610-270', 'RS', 'Brasil')
# 267 ('-29.99662233', '-51.21503323', 'Travessia Régis Bitencourt', None, 'Arquipélago', 'Porto Alegre', '90230-011', 'RS', 'Brasil')
# 268 ('-30.04403947', '-51.19237422', 'Rua Felipe de Oliveira', None, 'Petrópolis', 'Porto Alegre', '90460-000', 'RS', 'Brasil')
# 269 ('-30.05959781', '-51.2370412', None, None, 'Praia de Belas', 'Porto Alegre', '90020-020', 'RS', 'Brasil')
# 270 ('-30.00611988', '-51.24455701', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 271 ('-30.06252972', '-51.18197876', 'Rua O', None, 'Partenon', 'Porto Alegre', '90650-001', 'RS', 'Brasil')
# 272 ('-30.06356341', '-51.232575', None, None, 'Praia de Belas', 'Porto Alegre', '90850-110', 'RS', 'Brasil')
# 273 ('-30.00565876', '-51.23247173', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 274 ('-30.01732148', '-51.23022864', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 275 ('-30.03658926', '-51.2326794', 'Rua Washington Luiz', '820', 'Centro Histórico', 'Porto Alegre', '90010-460', 'RS', 'Brasil')
# 276 ('-30.06751301', '-51.22552229', 'Rua Professor Doutor Milton Guerreiro', None, 'Santa Tereza', 'Porto Alegre', '90850-300', 'RS', 'Brasil')
# 277 ('-30.06890819', '-51.20835737', 'Avenida Niterói', '472', 'Medianeira', 'Porto Alegre', '90880-270', 'RS', 'Brasil')
# 278 ('-30.05206672', '-51.24493673', None, None, 'Praia de Belas', 'Porto Alegre', '90050-190', 'RS', 'Brasil')
# 279 ('-30.03141403', '-51.2482072', 'Rua Ilha Mauá', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 280 ('-30.05546313', '-51.21154092', 'Avenida Professor Oscar Pereira', None, 'Azenha', 'Porto Alegre', '90160-006', 'RS', 'Brasil')
# 281 ('-30.05362228', '-51.21613701', 'Rua Visconde do Herval', None, 'Azenha', 'Porto Alegre', '90160-180', 'RS', 'Brasil')
# 282 ('-30.02939131', '-51.2649544', 'Beco 298', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 283 ('-30.01687104', '-51.18353129', 'Avenida Cristóvão Colombo', '3638', 'Higienópolis', 'Porto Alegre', '90540-000', 'RS', 'Brasil')
# 284 ('-30.06963241', '-51.22221462', 'Acesso 26', None, 'Santa Tereza', 'Porto Alegre', '90840-600', 'RS', 'Brasil')
# 285 ('-30.03922631', '-51.17095005', 'Rua João Bastian', None, '3 Figueiras', 'Porto Alegre', '90690-140', 'RS', 'Brasil')
# 286 ('-30.00217859', '-51.20755365', None, None, 'Navegantes', 'Porto Alegre', '90230-011', 'RS', 'Brasil')
# 287 ('-29.99931826', '-51.19972759', 'Rua Dona Margarida', None, 'Navegantes', 'Porto Alegre', '90220-003', 'RS', 'Brasil')
# 288 ('-30.04588643', '-51.20277829', 'Avenida Princesa Isabel', '1115', 'Santana', 'Porto Alegre', '90620-001', 'RS', 'Brasil')
# 289 ('-30.05163902', '-51.26329941', None, None, 'Arquipélago', 'Porto Alegre', None, 'RS', 'Brasil')
# 290 ('-30.07226201', '-51.19317022', None, None, 'Glória', 'Porto Alegre', '90680-540', 'RS', 'Brasil')
# 291 ('-30.05394005', '-51.24790869', None, None, 'Azenha', 'Porto Alegre', '90130-001', 'RS', 'Brasil')
# 292 ('-30.01954467', '-51.22400808', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 293 ('-29.9913698', '-51.20395795', 'Rua Voluntários da Pátria', '4455', 'Navegantes', 'Porto Alegre', '90230-011', 'RS', 'Brasil')
# 294 ('-30.0351965', '-51.2444239', None, None, 'Praia de Belas', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 295 ('-30.01629048', '-51.2342248', 'Faixa Portuária', None, 'Floresta', 'Porto Alegre', '90030-130', 'RS', 'Brasil')
# 296 ('-30.0051267', '-51.20693816', 'Avenida Missões', None, 'São Geraldo', 'Porto Alegre', '90230-110', 'RS', 'Brasil')
# 297 ('-30.03567603', '-51.26244755', 'Rua Marinheiros', None, 'Arquipélago', 'Porto Alegre', '90010-120', 'RS', 'Brasil')
# 298 ('-29.99661369', '-51.2034908', 'Rua Santo Guerra', '4389', 'Navegantes', 'Porto Alegre', '90240-100', 'RS', 'Brasil')
# 299 ('-30.03397123', '-51.17797984', 'Avenida Carlos Gomes', None, '3 Figueiras', 'Porto Alegre', '90470-260', 'RS', 'Brasil')
# 300 ('-30.0423951', '-51.18405455', 'Avenida Taquara', None, 'Petrópolis', 'Porto Alegre', '90460-160', 'RS', 'Brasil')
